# %% [markdown]
# <a href="https://colab.research.google.com/github/velkir/ChallengesDayN/blob/main/ChallengeDay26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1

# %%
import pandas as pd

date_range = pd.date_range(start="2021-01-01 00:00:00", end="2021-01-02", freq="1h", inclusive="left")
date_range
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 01:00:00',
#                '2021-01-01 02:00:00', '2021-01-01 03:00:00',
#                '2021-01-01 04:00:00', '2021-01-01 05:00:00',
#                '2021-01-01 06:00:00', '2021-01-01 07:00:00',
#                '2021-01-01 08:00:00', '2021-01-01 09:00:00',
#                '2021-01-01 10:00:00', '2021-01-01 11:00:00',
#                '2021-01-01 12:00:00', '2021-01-01 13:00:00',
#                '2021-01-01 14:00:00', '2021-01-01 15:00:00',
#                '2021-01-01 16:00:00', '2021-01-01 17:00:00',
#                '2021-01-01 18:00:00', '2021-01-01 19:00:00',
#                '2021-01-01 20:00:00', '2021-01-01 21:00:00',
#                '2021-01-01 22:00:00', '2021-01-01 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# 2

# %%
import numpy as np

start_date = "2021-03-01"
date_range = pd.date_range(start=start_date, periods=31)
df = pd.DataFrame(data=date_range, columns=["day"])
df["day_of_year"] = df["day"].dt.day_of_year
df
# start_date = "2021-03-01"
# end_date = "2021-03-31"
# date_range = pd.date_range(start_date, end_date, freq="1d")
# day_of_year = range(pd.Period(start_date).day_of_year, pd.Period(end_date).day_of_year+1, 1)
# pd.DataFrame(data={'day': date_range, "day_of_year": day_of_year})
# Out:
#           day  day_of_year
# 0  2021-03-01           60
# 1  2021-03-02           61
# 2  2021-03-03           62
# 3  2021-03-04           63
# 4  2021-03-05           64
# 5  2021-03-06           65
# 6  2021-03-07           66
# 7  2021-03-08           67
# 8  2021-03-09           68
# 9  2021-03-10           69
# 10 2021-03-11           70
# 11 2021-03-12           71
# 12 2021-03-13           72
# 13 2021-03-14           73
# 14 2021-03-15           74
# 15 2021-03-16           75
# 16 2021-03-17           76
# 17 2021-03-18           77
# 18 2021-03-19           78
# 19 2021-03-20           79
# 20 2021-03-21           80
# 21 2021-03-22           81
# 22 2021-03-23           82
# 23 2021-03-24           83
# 24 2021-03-25           84
# 25 2021-03-26           85
# 26 2021-03-27           86
# 27 2021-03-28           87
# 28 2021-03-29           88
# 29 2021-03-30           89
# 30 2021-03-31           90

# %% [markdown]
# 3

# %%
data_dict = {
    'normal': np.random.normal(loc=0, scale=1, size=1000),
    'uniform': np.random.uniform(low=0, high=1, size=1000),
    'binomial': np.random.binomial(n=1, p=0.2, size=1000)
}

date_range = pd.date_range(start="2020-01-01", periods = 1000)

df = pd.DataFrame(data=data_dict, index=date_range, columns=["normal", "uniform", "binomial"])
df
# Out:
#               normal   uniform  binomial
# 2020-01-01  0.739497  0.511051         1
# 2020-01-02 -0.935877  0.482952         0
# 2020-01-03 -2.708540  0.363113         0
# 2020-01-04  1.171417  0.343301         0
# 2020-01-05 -0.937869  0.407451         1
# ...              ...       ...       ...
# 2022-09-22 -0.844073  0.648722         0
# 2022-09-23 -0.965035  0.158918         0
# 2022-09-24  1.063398  0.210778         0
# 2022-09-25  0.244689  0.955279         0
# 2022-09-26 -0.042081  0.399862         0
#
# [1000 rows x 3 columns]

# %% [markdown]
# 4

# %%
data_dict = {
    'normal': np.random.normal(loc=0, scale=1, size=1000),
    'uniform': np.random.uniform(low=0, high=1, size=1000),
    'binomial': np.random.binomial(n=1, p=0.2, size=1000)
}

date_range = pd.date_range(start="2020-01-01", periods = 1000)

df = pd.DataFrame(data=data_dict, index=date_range, columns=["normal", "uniform", "binomial"])
print(df.head(10))
print()
print(df.tail(5))
# Out:
#               normal   uniform  binomial
# 2020-01-01 -1.586958  0.896493         0
# 2020-01-02 -0.083454  0.162686         0
# 2020-01-03 -0.809974  0.895689         1
# 2020-01-04 -0.029699  0.945882         0
# 2020-01-05  0.750810  0.723954         0
# 2020-01-06 -1.322413  0.535985         0
# 2020-01-07 -0.116103  0.754723         0
# 2020-01-08 -0.223918  0.686109         0
# 2020-01-09 -0.638003  0.351227         0
# 2020-01-10 -0.697702  0.517400         0
#
#               normal   uniform  binomial
# 2022-09-22  0.266830  0.691564         0
# 2022-09-23  1.759871  0.541591         0
# 2022-09-24 -1.239189  0.321220         0
# 2022-09-25 -1.139152  0.509431         0
# 2022-09-26  0.021182  0.229331         1

# %% [markdown]
# 5

# %%
data_dict = {
    'normal': np.random.normal(loc=0, scale=1, size=1000),
    'uniform': np.random.uniform(low=0, high=1, size=1000),
    'binomial': np.random.binomial(n=1, p=0.2, size=1000)
}

date_range = pd.date_range(start="2020-01-01", periods = 1000)

df = pd.DataFrame(data=data_dict, index=date_range, columns=["normal", "uniform", "binomial"])

print(df.info())
print()
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1000 entries, 2020-01-01 to 2022-09-26
# Freq: D
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   normal    1000 non-null   float64
#  1   uniform   1000 non-null   float64
#  2   binomial  1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 31.2 KB
# None
#
#             normal      uniform     binomial
# count  1000.000000  1000.000000  1000.000000
# mean     -0.049146     0.486688     0.189000
# std       0.992875     0.287876     0.391705
# min      -3.162199     0.000943     0.000000
# 25%      -0.746685     0.248473     0.000000
# 50%      -0.075695     0.471048     0.000000
# 75%       0.617911     0.740053     0.000000
# max       3.300176     0.999659     1.000000

# %% [markdown]
# 6

# %%
import numpy as np
import pandas as pd


np.random.seed(42)
data_dict = {
    'normal': np.random.normal(loc=0, scale=1, size=1000),
    'uniform': np.random.uniform(low=0, high=1, size=1000),
    'binomial': np.random.binomial(n=1, p=0.2, size=1000),
}

df = pd.DataFrame(
    data=data_dict, index=pd.date_range('2020-01-01', periods=1000)
)

print(df["binomial"].value_counts())
# Out:
# binomial
# 0    808
# 1    192
# Name: count, dtype: int64
